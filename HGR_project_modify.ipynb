# %%
import numpy as np  
import h5py
from PIL import Image
import matplotlib.pyplot as plt
import os
import cv2

from google.colab import drive

import sys
import pickle
from keras.optimizers import SGD, Adam, Nadam
from keras.callbacks import *
#from keras.objectives import *
from keras.metrics import binary_accuracy
from keras.models import load_model
import keras.backend as K
from keras.preprocessing.image import *
from keras.utils.np_utils import to_categorical
from sklearn.metrics import f1_score
from keras import optimizers
import time




drive.mount('/content/drive',force_remount=True)
# adding Segmentation to the system path
sys.path.insert(0, '/content/drive/MyDrive/CV_project_HGR')
sys.path.insert(0, '/content/drive/MyDrive/CV_project_HGR/Segmentation')
from Full_Model_modify import FullModel
from Seg_model_modify import SegModel
# Out:
# Mounted at /content/drive

# %%
#########
from keras.layers import Dense, Dropout, Activation, \
                         Flatten, Convolution2D, MaxPooling2D, \
                         BatchNormalization, Conv2D, Input,AveragePooling2D,UpSampling2D
from keras.models import Model
#########

# %%
#######################
### Load Train data ###
#######################
train_root = "/content/drive/MyDrive/CV_project_HGR/datasets/train" 

train_image_path = os.path.join(train_root,"train_color")
train_target_image_path = os.path.join(train_root,"train_segmentation")

train_image_path_list = []
train_target_image_path_list = []

for filepath in os.listdir(train_image_path):
    train_image_path_list.append(os.path.join(train_image_path, filepath))
for filepath in os.listdir(train_target_image_path):
    train_target_image_path_list.append(os.path.join(train_target_image_path, filepath))

trainX = []
trainY = []

img_dim = (480, 480)

train_image_path_list = sorted(train_image_path_list)
m = len(train_image_path_list)
for i in range(len(train_image_path_list)):
    img = Image.open(str(train_image_path_list[i]))
    arr = np.array(img.resize(img_dim))
    trainX.append(arr)

train_target_image_path_list = sorted(train_target_image_path_list)
m = len(train_target_image_path_list)
for j in range(len(train_target_image_path_list)):
    img = Image.open(str(train_target_image_path_list[j]))
    arr = np.array(img.resize(img_dim))
    trainY.append(arr)

## Train data
# train input
trainImages = np.array(trainX)
trainImages = trainImages.astype('float32')
trainImages /= 255.0
# train target
trainMasks = np.array(trainY)
trainMasks[trainMasks > 0] = 255
trainMasks[trainMasks <= 0] = 0
trainMasks = trainMasks.astype('float32')
trainMasks /= 255.0

# %%
print(trainImages.shape)
print(trainMasks.shape)
# Out:
# (2000, 480, 480, 3)
# (2000, 480, 480)

# %%
####################
### Segmentation ###
####################
## Parameter setting
batch_size = 2
epochs = 200
learningRate = 0.001
ch = 3

## Fscore evaluation 
def fscore(tp,Images,Masks):
    total=0
    i=0
    fs=0

    m, height, weight = Masks.shape
    _Masks = np.zeros([m, height, weight, 1])
    for i in range(len(Images)):
        total += 1

        tp[i][tp[i]>0.5]=1
        tp[i][tp[i]<0.5]=0

        pred = img_to_array(tp[i]).astype(int)
        _Masks[i] = Masks[i].reshape((len(Masks[i][0]), len(Masks[i][1]), 1))
        label = img_to_array(np.squeeze(_Masks[i], axis=2)).astype(int)
        #pred = tp[i]
        #label = Masks[i]
        flat_pred = np.ravel(pred)
        flat_label = np.ravel(label)

        fs += f1_score(flat_label,flat_pred, average='micro')

    fs=fs/total

    return fs  

#### Compile segmentation model ####
input_size = (img_dim[0], img_dim[1], ch)
SegM_modify = SegModel(input_size)
model = SegM_modify.model
adam_optimizer = optimizers.Adam(learning_rate=learningRate, beta_1=0.9, beta_2=0.999, decay=0.0)
model.compile(loss='binary_crossentropy',optimizer = adam_optimizer,metrics=['accuracy'])
checkpoint_filepath = '/content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify'
model_checkpoint = ModelCheckpoint(checkpoint_filepath, monitor='val_acc',verbose=1, save_weights_only=True)

## train data
start = time.time()
hist = model.fit(trainImages, trainMasks, batch_size=batch_size, epochs=epochs, verbose=1,callbacks=[model_checkpoint])
print(time.time()-start)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 480, 480, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 480, 480, 16  448         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 480, 480, 16  64         ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  re_lu_13 (ReLU)                (None, 480, 480, 16  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 480, 480, 96  1536        ['re_lu_13[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 480, 480, 96  384        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  re_lu_14 (ReLU)                (None, 480, 480, 96  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 481, 481, 96  0          ['re_lu_14[0][0]']
#  D)                             )
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 240, 240, 96  864        ['zero_padding2d_2[0][0]']
#  onv2D)                         )
#
#  batch_normalization_22 (BatchN  (None, 240, 240, 96  384        ['depthwise_conv2d_6[0][0]']
#  ormalization)                  )
#
#  re_lu_15 (ReLU)                (None, 240, 240, 96  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 240, 240, 32  3072        ['re_lu_15[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 240, 240, 32  128        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  conv2d_22 (Conv2D)             (None, 240, 240, 19  6144        ['batch_normalization_23[0][0]']
#                                 2)
#
#  batch_normalization_24 (BatchN  (None, 240, 240, 19  768        ['conv2d_22[0][0]']
#  ormalization)                  2)
#
#  re_lu_16 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_24[0][0]']
#                                 2)
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 240, 240, 19  1728       ['re_lu_16[0][0]']
#  onv2D)                         2)
#
#  batch_normalization_25 (BatchN  (None, 240, 240, 19  768        ['depthwise_conv2d_7[0][0]']
#  ormalization)                  2)
#
#  re_lu_17 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_25[0][0]']
#                                 2)
#
#  conv2d_23 (Conv2D)             (None, 240, 240, 32  6144        ['re_lu_17[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 240, 240, 32  128        ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  add_4 (Add)                    (None, 240, 240, 32  0           ['batch_normalization_26[0][0]',
#                                 )                                 'batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 240, 240, 19  6144        ['add_4[0][0]']
#                                 2)
#
#  batch_normalization_27 (BatchN  (None, 240, 240, 19  768        ['conv2d_24[0][0]']
#  ormalization)                  2)
#
#  re_lu_18 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_27[0][0]']
#                                 2)
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 240, 240, 19  1728       ['re_lu_18[0][0]']
#  onv2D)                         2)
#
#  batch_normalization_28 (BatchN  (None, 240, 240, 19  768        ['depthwise_conv2d_8[0][0]']
#  ormalization)                  2)
#
#  re_lu_19 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_28[0][0]']
#                                 2)
#
#  conv2d_25 (Conv2D)             (None, 240, 240, 32  6144        ['re_lu_19[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 240, 240, 32  128        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  add_5 (Add)                    (None, 240, 240, 32  0           ['batch_normalization_29[0][0]',
#                                 )                                 'add_4[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 240, 240, 19  6144        ['add_5[0][0]']
#                                 2)
#
#  batch_normalization_30 (BatchN  (None, 240, 240, 19  768        ['conv2d_26[0][0]']
#  ormalization)                  2)
#
#  re_lu_20 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_30[0][0]']
#                                 2)
#
#  zero_padding2d_3 (ZeroPadding2  (None, 241, 241, 19  0          ['re_lu_20[0][0]']
#  D)                             2)
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 120, 120, 19  1728       ['zero_padding2d_3[0][0]']
#  onv2D)                         2)
#
#  batch_normalization_31 (BatchN  (None, 120, 120, 19  768        ['depthwise_conv2d_9[0][0]']
#  ormalization)                  2)
#
#  re_lu_21 (ReLU)                (None, 120, 120, 19  0           ['batch_normalization_31[0][0]']
#                                 2)
#
#  conv2d_27 (Conv2D)             (None, 120, 120, 64  12288       ['re_lu_21[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 120, 120, 64  256        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  conv2d_28 (Conv2D)             (None, 120, 120, 38  24576       ['batch_normalization_32[0][0]']
#                                 4)
#
#  batch_normalization_33 (BatchN  (None, 120, 120, 38  1536       ['conv2d_28[0][0]']
#  ormalization)                  4)
#
#  re_lu_22 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_33[0][0]']
#                                 4)
#
#  depthwise_conv2d_10 (Depthwise  (None, 120, 120, 38  3456       ['re_lu_22[0][0]']
#  Conv2D)                        4)
#
#  batch_normalization_34 (BatchN  (None, 120, 120, 38  1536       ['depthwise_conv2d_10[0][0]']
#  ormalization)                  4)
#
#  re_lu_23 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_34[0][0]']
#                                 4)
#
#  conv2d_29 (Conv2D)             (None, 120, 120, 64  24576       ['re_lu_23[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 120, 120, 64  256        ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  add_6 (Add)                    (None, 120, 120, 64  0           ['batch_normalization_35[0][0]',
#                                 )                                 'batch_normalization_32[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 120, 120, 38  24576       ['add_6[0][0]']
#                                 4)
#
#  batch_normalization_36 (BatchN  (None, 120, 120, 38  1536       ['conv2d_30[0][0]']
#  ormalization)                  4)
#
#  re_lu_24 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_36[0][0]']
#                                 4)
#
#  depthwise_conv2d_11 (Depthwise  (None, 120, 120, 38  3456       ['re_lu_24[0][0]']
#  Conv2D)                        4)
#
#  batch_normalization_37 (BatchN  (None, 120, 120, 38  1536       ['depthwise_conv2d_11[0][0]']
#  ormalization)                  4)
#
#  re_lu_25 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_37[0][0]']
#                                 4)
#
#  conv2d_31 (Conv2D)             (None, 120, 120, 64  24576       ['re_lu_25[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 120, 120, 64  256        ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  add_7 (Add)                    (None, 120, 120, 64  0           ['batch_normalization_38[0][0]',
#                                 )                                 'add_6[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 120, 120, 64  256        ['add_7[0][0]']
#  ormalization)                  )
#
#  activation_1 (Activation)      (None, 120, 120, 64  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 120, 120, 32  2080        ['activation_1[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 120, 120, 16  0           ['conv2d_32[0][0]',
#                                 0)                                'conv2d_33[0][0]',
#                                                                   'conv2d_34[0][0]',
#                                                                   'conv2d_35[0][0]',
#                                                                   'conv2d_36[0][0]']
#
#  dropout_1 (Dropout)            (None, 120, 120, 16  0           ['concatenate_1[0][0]']
#                                 0)
#
#  conv2d_37 (Conv2D)             (None, 120, 120, 1)  161         ['dropout_1[0][0]']
#
#  bilinear_up_sampling2d_1 (Bili  (None, 480, 480, 1)  0          ['conv2d_37[0][0]']
#  nearUpSampling2D)
#
# ==================================================================================================
# Total params: 248,417
# Trainable params: 241,921
# Non-trainable params: 6,496
# __________________________________________________________________________________________________
# Epoch 1/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9688
# Epoch 1: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 60s 48ms/step - loss: 0.0804 - accuracy: 0.9688
# Epoch 2/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9811
# Epoch 2: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 46s 46ms/step - loss: 0.0480 - accuracy: 0.9811
# Epoch 3/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9837
# Epoch 3: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0413 - accuracy: 0.9837
# Epoch 4/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0375 - accuracy: 0.9850
# Epoch 4: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0375 - accuracy: 0.9850
# Epoch 5/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9851
# Epoch 5: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0371 - accuracy: 0.9851
# Epoch 6/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9863
# Epoch 6: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0339 - accuracy: 0.9863
# Epoch 7/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9857
# Epoch 7: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0355 - accuracy: 0.9857
# Epoch 8/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9869
# Epoch 8: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0322 - accuracy: 0.9869
# Epoch 9/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.9868
# Epoch 9: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0327 - accuracy: 0.9868
# Epoch 10/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0307 - accuracy: 0.9874
# Epoch 10: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0307 - accuracy: 0.9874
# Epoch 11/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9877
# Epoch 11: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0300 - accuracy: 0.9877
# Epoch 12/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0292 - accuracy: 0.9880
# Epoch 12: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0292 - accuracy: 0.9879
# Epoch 13/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0296 - accuracy: 0.9878
# Epoch 13: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0296 - accuracy: 0.9878
# Epoch 14/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9881
# Epoch 14: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0287 - accuracy: 0.9881
# Epoch 15/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0283 - accuracy: 0.9883
# Epoch 15: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0283 - accuracy: 0.9883
# Epoch 16/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9884
# Epoch 16: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0278 - accuracy: 0.9884
# Epoch 17/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0272 - accuracy: 0.9887
# Epoch 17: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0272 - accuracy: 0.9887
# Epoch 18/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9883
# Epoch 18: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0281 - accuracy: 0.9883
# Epoch 19/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9888
# Epoch 19: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0268 - accuracy: 0.9888
# Epoch 20/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9890
# Epoch 20: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0263 - accuracy: 0.9890
# Epoch 21/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9883
# Epoch 21: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0282 - accuracy: 0.9883
# Epoch 22/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9892
# Epoch 22: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0259 - accuracy: 0.9892
# Epoch 23/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9893
# Epoch 23: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0257 - accuracy: 0.9893
# Epoch 24/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9893
# Epoch 24: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0256 - accuracy: 0.9893
# Epoch 25/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9894
# Epoch 25: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0254 - accuracy: 0.9894
# Epoch 26/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9896
# Epoch 26: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0249 - accuracy: 0.9896
# Epoch 27/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9896
# Epoch 27: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0249 - accuracy: 0.9896
# Epoch 28/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 0.9897
# Epoch 28: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0246 - accuracy: 0.9897
# Epoch 29/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9898
# Epoch 29: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0244 - accuracy: 0.9898
# Epoch 30/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9899
# Epoch 30: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0240 - accuracy: 0.9899
# Epoch 31/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9899
# Epoch 31: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0240 - accuracy: 0.9899
# Epoch 32/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9901
# Epoch 32: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0237 - accuracy: 0.9901
# Epoch 33/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0243 - accuracy: 0.9898
# Epoch 33: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0243 - accuracy: 0.9898
# Epoch 34/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9901
# Epoch 34: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0235 - accuracy: 0.9901
# Epoch 35/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9904
# Epoch 35: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0229 - accuracy: 0.9904
# Epoch 36/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0229 - accuracy: 0.9904
# Epoch 36: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0229 - accuracy: 0.9904
# Epoch 37/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9904
# Epoch 37: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0228 - accuracy: 0.9904
# Epoch 38/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9905
# Epoch 38: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0225 - accuracy: 0.9905
# Epoch 39/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9906
# Epoch 39: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0223 - accuracy: 0.9906
# Epoch 40/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9905
# Epoch 40: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0226 - accuracy: 0.9905
# Epoch 41/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 0.9907
# Epoch 41: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0220 - accuracy: 0.9907
# Epoch 42/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9907
# Epoch 42: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0220 - accuracy: 0.9907
# Epoch 43/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9909
# Epoch 43: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0217 - accuracy: 0.9909
# Epoch 44/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9909
# Epoch 44: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0215 - accuracy: 0.9909
# Epoch 45/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 0.9910
# Epoch 45: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0214 - accuracy: 0.9910
# Epoch 46/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0211 - accuracy: 0.9911
# Epoch 46: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.
200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9943
# Epoch 176: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0137 - accuracy: 0.9943
# Epoch 177/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9944
# Epoch 177: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0135 - accuracy: 0.9944
# Epoch 178/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9944
# Epoch 178: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0136 - accuracy: 0.9944
# Epoch 179/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9944
# Epoch 179: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0136 - accuracy: 0.9944
# Epoch 180/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9944
# Epoch 180: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0136 - accuracy: 0.9944
# Epoch 181/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9945
# Epoch 181: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0134 - accuracy: 0.9945
# Epoch 182/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0134 - accuracy: 0.9944
# Epoch 182: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0134 - accuracy: 0.9944
# Epoch 183/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9944
# Epoch 183: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0134 - accuracy: 0.9944
# Epoch 184/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9944
# Epoch 184: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0135 - accuracy: 0.9944
# Epoch 185/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9944
# Epoch 185: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0134 - accuracy: 0.9944
# Epoch 186/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0134 - accuracy: 0.9945
# Epoch 186: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0134 - accuracy: 0.9945
# Epoch 187/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0134 - accuracy: 0.9945
# Epoch 187: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0134 - accuracy: 0.9945
# Epoch 188/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9945
# Epoch 188: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0133 - accuracy: 0.9945
# Epoch 189/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9945
# Epoch 189: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 47s 47ms/step - loss: 0.0133 - accuracy: 0.9945
# Epoch 190/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0133 - accuracy: 0.9945
# Epoch 190: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0133 - accuracy: 0.9945
# Epoch 191/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9945
# Epoch 191: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0133 - accuracy: 0.9945
# Epoch 192/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0133 - accuracy: 0.9945
# Epoch 192: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0133 - accuracy: 0.9945
# Epoch 193/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0133 - accuracy: 0.9945
# Epoch 193: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0133 - accuracy: 0.9945
# Epoch 194/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0133 - accuracy: 0.9945
# Epoch 194: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0133 - accuracy: 0.9945
# Epoch 195/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9945
# Epoch 195: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0132 - accuracy: 0.9945
# Epoch 196/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9946
# Epoch 196: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0132 - accuracy: 0.9946
# Epoch 197/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9945
# Epoch 197: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0132 - accuracy: 0.9945
# Epoch 198/200
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0132 - accuracy: 0.9945
# Epoch 198: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0132 - accuracy: 0.9945
# Epoch 199/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9945
# Epoch 199: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0133 - accuracy: 0.9945
# Epoch 200/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9945
# Epoch 200: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfile_modify
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.0132 - accuracy: 0.9945
# 9524.838790416718

# %%
#######################
### Load Test data ###
#######################
test_root = "/content/drive/MyDrive/CV_project_HGR/datasets/test"

test_image_path = os.path.join(test_root,"test_color")
test_target_image_path = os.path.join(test_root,"test_segmentation")

test_image_path_list = []
test_target_image_path_list = []

for filepath in os.listdir(test_image_path):
    test_image_path_list.append(os.path.join(test_image_path, filepath))
for filepath in os.listdir(test_target_image_path):
    test_target_image_path_list.append(os.path.join(test_target_image_path, filepath))

testX = []
testY = []
img_dim = (480, 480)

test_image_path_list = sorted(test_image_path_list)
for i in range(len(test_image_path_list)):
    img = Image.open(str(test_image_path_list[i]))
    arr = np.array(img.resize(img_dim))
    testX.append(arr)

test_target_image_path_list = sorted(test_target_image_path_list)
for j in range(len(test_target_image_path_list)):
    img = Image.open(str(test_target_image_path_list[j]))
    arr = np.array(img.resize(img_dim))
    testY.append(arr)

## Test data
, 0.015043357387185097, 0.014931248500943184, 0.014838417991995811, 0.014808569103479385, 0.014817867428064346, 0.014824791811406612, 0.014648227021098137, 0.014681294560432434, 0.014666778966784477, 0.014600364491343498, 0.014619683846831322, 0.014570733532309532, 0.014531824737787247, 0.014526445418596268, 0.014434563927352428, 0.014451335184276104, 0.014462015591561794, 0.014468378387391567, 0.014523214660584927, 0.014338319189846516, 0.014284242875874043, 0.014328457415103912, 0.014297226443886757, 0.014228486455976963, 0.014234752394258976, 0.014183320105075836, 0.014071174897253513, 0.014095827005803585, 0.014033799059689045, 0.014150416478514671, 0.014100877568125725, 0.014042472466826439, 0.01390419527888298, 0.013958154246211052, 0.014038443565368652, 0.013910475187003613, 0.013883600942790508, 0.013855569064617157, 0.013937926851212978, 0.013786275871098042, 0.013795937411487103, 0.013798961415886879, 0.013735253363847733, 0.013722186908125877, 0.013769786804914474, 0.013865634799003601, 0.013604160398244858, 0.013628078624606133, 0.013626179657876492, 0.013555110432207584, 0.013650539331138134, 0.013515320606529713, 0.013595893047749996, 0.013552604243159294, 0.013582638464868069, 0.01341030839830637, 0.013423124328255653, 0.013427398167550564 ...
# fscore = 0.9032437760416661

# %%
print(y_pred.shape)
fig, axarr = plt.subplots(5, 3, figsize=(6, 10))
fig.tight_layout()
for i in range(5):
    axarr[i][0].set_title('original')
    axarr[i][0].imshow(testImages[300+i])
    axarr[i][1].set_title('predict')
    axarr[i][1].imshow(y_pred[300+i], cmap='gray')
    axarr[i][2].set_title('mask')
    axarr[i][2].imshow(testMasks[300+i], cmap='gray')

# %%
import os
import sys
from keras.callbacks import *
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

sys.path.insert(0, '/content/drive/MyDrive/CV_project_HGR')
from Full_Model_modify import FullModel

## Parameter setting
input_size=(480,480,3)
class_name = ["A", "B", "C", "D", "E", "F", "H", "I", "J", "K"]
num_class = 10
learningRate = 0.001
batch_size = 2
epochs = 50
num_train = 2000
num_test = 1000

trainLabel = []
for i in range(len(train_image_path_list)):
  char = train_image_path_list[i].split("/")[-1].split("-")[0]
  if char == "A":
    trainLabel.append(0)
  elif char == "B":
    trainLabel.append(1)
  elif char == "C":
    trainLabel.append(2)
  elif char == "D":
    trainLabel.append(3)
  elif char == "E":
    trainLabel.append(4)
  elif char == "F":
    trainLabel.append(5)
  elif char == "H":
    trainLabel.append(6)
  elif char == "I":
    trainLabel.append(7)
  elif char == "J":
    trainLabel.append(8)
  elif char == "K":
    trainLabel.append(9)
  else:
    print(char)
    print("wrong")
    break


trainLabel = to_categorical(trainLabel, num_classes=num_class, dtype='uint8')
#print(trainLabel.shape)

testLabel = []
for i in range(len(test_image_path_list)):
  char = test_image_path_list[i].split("/")[-1].split("-")[0]
  if char == "A":
    testLabel.append(0)
  elif char == "B":
    testLabel.append(1)
  elif char == "C":
    testLabel.append(2)
  elif char == "D":
    testLabel.append(3)
  elif char == "E":
    testLabel.append(4)
  elif char == "F":
    testLabel.append(5)
  elif char == "H":
    testLabel.append(6)
  elif char == "I":
    testLabel.append(7)
  elif char == "J":
    testLabel.append(8)
  elif char == "K":
    testLabel.append(9)
  else:
    print(char)
    print("wrong")
    break

testLabel = to_categorical(testLabel, num_classes=num_class, dtype='uint8')
# print(testLabel)
# print(testLabel.shape)

## image augument
train_datagen = ImageDataGenerator(
        rotation_range=40,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=False,
        width_shift_range=0.2,
        height_shift_range=0.2,
        fill_mode='nearest')

test_datagen = ImageDataGenerator()



train_root = "/content/drive/MyDrive/CV_project_HGR/datasets/train"
# train_generator = train_datagen.flow_from_directory(
#         train_root,  # target directory
#         target_size=(480, 480),  
#         batch_size=2,
#         class_mode='categorical')  # since we use binary_crossentropy loss, we need binary labels
train_generator = train_datagen.flow(trainImages, trainLabel, batch_size=batch_size)

## check image after augmentation
# for _ in range(5):
#     img, label = train_generator.next()
#     print(img.shape)   #  (1,256,256,3)
#     plt.imshow(img[0])
#     plt.show()

test_root = "/content/drive/MyDrive/CV_project_HGR/datasets/test"
# test_generator = test_datagen.flow_from_directory(
#         test_root,
#         target_size=(480, 480),
#         batch_size=2,
#         class_mode='categorical')
test_generator = test_datagen.flow(testImages, testLabel, batch_size=batch_size)

# for _ in range(5):
#     img, label = test_generator.next()
#     print(img.shape)   #  (1,256,256,3)
#     plt.imshow(img[0])
#     plt.show()

# %%
####################################################
### Start to Train full model and classification ###
####################################################
#####Compile####
FullM = FullModel(input_size,num_class)
model = FullM.model_Final
adam_optimizer = optimizers.Adam(learning_rate=learningRate, beta_1=0.9, beta_2=0.999, decay=0.0)
model.compile(loss='binary_crossentropy',optimizer=adam_optimizer,metrics=['accuracy'])

checkpointFull_filepath = '/content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify'

model_checkpoint_full = ModelCheckpoint(checkpointFull_filepath, monitor='val_acc',verbose=1, save_weights_only=True)

start_2 = time.time()
model.fit_generator(
        train_generator,
        steps_per_epoch=num_train // batch_size,
        epochs=epochs,
        validation_data=test_generator,
        validation_steps=num_test // batch_size,
        callbacks=[model_checkpoint_full])
print(time.time()-start_2)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 480, 480, 3  0           []
#                                 )]
#
#  conv2d_25 (Conv2D)             (None, 480, 480, 16  448         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 480, 480, 16  64         ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  re_lu_25 (ReLU)                (None, 480, 480, 16  0           ['batch_normalization_32[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 480, 480, 96  1536        ['re_lu_25[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 480, 480, 96  384        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  re_lu_26 (ReLU)                (None, 480, 480, 96  0           ['batch_normalization_33[0][0]']
#                                 )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 481, 481, 96  0          ['re_lu_26[0][0]']
#  D)                             )
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 240, 240, 96  864        ['zero_padding2d_2[0][0]']
#  onv2D)                         )
#
#  batch_normalization_34 (BatchN  (None, 240, 240, 96  384        ['depthwise_conv2d_6[0][0]']
#  ormalization)                  )
#
#  re_lu_27 (ReLU)                (None, 240, 240, 96  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 240, 240, 32  3072        ['re_lu_27[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 240, 240, 32  128        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  conv2d_28 (Conv2D)             (None, 240, 240, 19  6144        ['batch_normalization_35[0][0]']
#                                 2)
#
#  batch_normalization_36 (BatchN  (None, 240, 240, 19  768        ['conv2d_28[0][0]']
#  ormalization)                  2)
#
#  re_lu_28 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_36[0][0]']
#                                 2)
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 240, 240, 19  1728       ['re_lu_28[0][0]']
#  onv2D)                         2)
#
#  batch_normalization_37 (BatchN  (None, 240, 240, 19  768        ['depthwise_conv2d_7[0][0]']
#  ormalization)                  2)
#
#  re_lu_29 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_37[0][0]']
#                                 2)
#
#  conv2d_29 (Conv2D)             (None, 240, 240, 32  6144        ['re_lu_29[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 240, 240, 32  128        ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  add_5 (Add)                    (None, 240, 240, 32  0           ['batch_normalization_38[0][0]',
#                                 )                                 'batch_normalization_35[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 240, 240, 19  6144        ['add_5[0][0]']
#                                 2)
#
#  batch_normalization_39 (BatchN  (None, 240, 240, 19  768        ['conv2d_30[0][0]']
#  ormalization)                  2)
#
#  re_lu_30 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_39[0][0]']
#                                 2)
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 240, 240, 19  1728       ['re_lu_30[0][0]']
#  onv2D)                         2)
#
#  batch_normalization_40 (BatchN  (None, 240, 240, 19  768        ['depthwise_conv2d_8[0][0]']
#  ormalization)                  2)
#
#  re_lu_31 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_40[0][0]']
#                                 2)
#
#  conv2d_31 (Conv2D)             (None, 240, 240, 32  6144        ['re_lu_31[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 240, 240, 32  128        ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  add_6 (Add)                    (None, 240, 240, 32  0           ['batch_normalization_41[0][0]',
#                                 )                                 'add_5[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 240, 240, 19  6144        ['add_6[0][0]']
#                                 2)
#
#  batch_normalization_42 (BatchN  (None, 240, 240, 19  768        ['conv2d_32[0][0]']
#  ormalization)                  2)
#
#  re_lu_32 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_42[0][0]']
#                                 2)
#
#  zero_padding2d_3 (ZeroPadding2  (None, 241, 241, 19  0          ['re_lu_32[0][0]']
#  D)                             2)
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 120, 120, 19  1728       ['zero_padding2d_3[0][0]']
#  onv2D)                         2)
#
#  batch_normalization_43 (BatchN  (None, 120, 120, 19  768        ['depthwise_conv2d_9[0][0]']
#  ormalization)                  2)
#
#  re_lu_33 (ReLU)                (None, 120, 120, 19  0           ['batch_normalization_43[0][0]']
#                                 2)
#
#  conv2d_33 (Conv2D)             (None, 120, 120, 64  12288       ['re_lu_33[0][0]']
#                                 )
#
#  batch_normalization_44 (BatchN  (None, 120, 120, 64  256        ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  conv2d_34 (Conv2D)             (None, 120, 120, 38  24576       ['batch_normalization_44[0][0]']
#                                 4)
#
#  batch_normalization_45 (BatchN  (None, 120, 120, 38  1536       ['conv2d_34[0][0]']
#  ormalization)                  4)
#
#  re_lu_34 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_45[0][0]']
#                                 4)
#
#  depthwise_conv2d_10 (Depthwise  (None, 120, 120, 38  3456       ['re_lu_34[0][0]']
#  Conv2D)                        4)
#
#  batch_normalization_46 (BatchN  (None, 120, 120, 38  1536       ['depthwise_conv2d_10[0][0]']
#  ormalization)                  4)
#
#  re_lu_35 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_46[0][0]']
#                                 4)
#
#  conv2d_35 (Conv2D)             (None, 120, 120, 64  24576       ['re_lu_35[0][0]']
#                                 )
#
#  batch_normalization_47 (BatchN  (None, 120, 120, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  add_7 (Add)                    (None, 120, 120, 64  0           ['batch_normalization_47[0][0]',
#                                 )                                 'batch_normalization_44[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 120, 120, 38  24576       ['add_7[0][0]']
#                                 4)
#
#  batch_normalization_48 (BatchN  (None, 120, 120, 38  1536       ['conv2d_36[0][0]']
#  ormalization)                  4)
#
#  re_lu_36 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_48[0][0]']
#                                 4)
#
#  depthwise_conv2d_11 (Depthwise  (None, 120, 120, 38  3456       ['re_lu_36[0][0]']
#  Conv2D)                        4)
#
#  batch_normalization_49 (BatchN  (None, 120, 120, 38  1536       ['depthwise_conv2d_11[0][0]']
#  ormalization)                  4)
#
#  re_lu_37 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_49[0][0]']
#                                 4)
#
#  conv2d_37 (Conv2D)             (None, 120, 120, 64  24576       ['re_lu_37[0][0]']
#                                 )
#
#  batch_normalization_50 (BatchN  (None, 120, 120, 64  256        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  add_8 (Add)                    (None, 120, 120, 64  0           ['batch_normalization_50[0][0]',
#                                 )                                 'add_7[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 120, 120, 64  256        ['add_8[0][0]']
#  ormalization)                  )
#
#  activation_1 (Activation)      (None, 120, 120, 64  0           ['batch_normalization_51[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 120, 120, 32  2080        ['activation_1[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 120, 120, 16  0           ['conv2d_38[0][0]',
#                                 0)                                'conv2d_39[0][0]',
#                                                                   'conv2d_40[0][0]',
#                                                                   'conv2d_41[0][0]',
#                                                                   'conv2d_42[0][0]']
#
#  dropout_5 (Dropout)            (None, 120, 120, 16  0           ['concatenate_1[0][0]']
#                                 0)
#
#  conv2d_43 (Conv2D)             (None, 120, 120, 1)  161         ['dropout_5[0][0]']
#
#  bilinear_up_sampling2d_1 (Bili  (None, 480, 480, 1)  0          ['conv2d_43[0][0]']
#  nearUpSampling2D)
#
# ==================================================================================================
# Total params: 248,417
# Trainable params: 241,921
# Non-trainable params: 6,496
# __________________________________________________________________________________________________
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 480, 480, 3  0           []
#                                 )]
#
#  conv2d_25 (Conv2D)             (None, 480, 480, 16  448         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 480, 480, 16  64         ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  re_lu_25 (ReLU)                (None, 480, 480, 16  0           ['batch_normalization_32[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 480, 480, 96  1536        ['re_lu_25[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 480, 480, 96  384        ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  re_lu_26 (ReLU)                (None, 480, 480, 96  0           ['batch_normalization_33[0][0]']
#                                 )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 481, 481, 96  0          ['re_lu_26[0][0]']
#  D)                             )
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 240, 240, 96  864        ['zero_padding2d_2[0][0]']
#  onv2D)                         )
#
#  batch_normalization_34 (BatchN  (None, 240, 240, 96  384        ['depthwise_conv2d_6[0][0]']
#  ormalization)                  )
#
#  re_lu_27 (ReLU)                (None, 240, 240, 96  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 240, 240, 32  3072        ['re_lu_27[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 240, 240, 32  128        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  conv2d_28 (Conv2D)             (None, 240, 240, 19  6144        ['batch_normalization_35[0][0]']
#                                 2)
#
#  batch_normalization_36 (BatchN  (None, 240, 240, 19  768        ['conv2d_28[0][0]']
#  ormalization)                  2)
#
#  re_lu_28 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_36[0][0]']
#                                 2)
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 240, 240, 19  1728       ['re_lu_28[0][0]']
#  onv2D)                         2)
#
#  batch_normalization_37 (BatchN  (None, 240, 240, 19  768        ['depthwise_conv2d_7[0][0]']
#  ormalization)                  2)
#
#  re_lu_29 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_37[0][0]']
#                                 2)
#
#  conv2d_29 (Conv2D)             (None, 240, 240, 32  6144        ['re_lu_29[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 240, 240, 32  128        ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  add_5 (Add)                    (None, 240, 240, 32  0           ['batch_normalization_38[0][0]',
#                                 )                                 'batch_normalization_35[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 240, 240, 19  6144        ['add_5[0][0]']
#                                 2)
#
#  batch_normalization_39 (BatchN  (None, 240, 240, 19  768        ['conv2d_30[0][0]']
#  ormalization)                  2)
#
#  re_lu_30 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_39[0][0]']
#                                 2)
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 240, 240, 19  1728       ['re_lu_30[0][0]']
#  onv2D)                         2)
#
#  batch_normalization_40 (BatchN  (None, 240, 240, 19  768        ['depthwise_conv2d_8[0][0]']
#  ormalization)                  2)
#
#  re_lu_31 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_40[0][0]']
#                                 2)
#
#  conv2d_31 (Conv2D)             (None, 240, 240, 32  6144        ['re_lu_31[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 240, 240, 32  128        ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  add_6 (Add)                    (None, 240, 240, 32  0           ['batch_normalization_41[0][0]',
#                                 )                                 'add_5[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 240, 240, 19  6144        ['add_6[0][0]']
#                                 2)
#
#  batch_normalization_42 (BatchN  (None, 240, 240, 19  768        ['conv2d_32[0][0]']
#  ormalization)                  2)
#
#  re_lu_32 (ReLU)                (None, 240, 240, 19  0           ['batch_normalization_42[0][0]']
#                                 2)
#
#  zero_padding2d_3 (ZeroPadding2  (None, 241, 241, 19  0          ['re_lu_32[0][0]']
#  D)                             2)
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 120, 120, 19  1728       ['zero_padding2d_3[0][0]']
#  onv2D)                         2)
#
#  batch_normalization_43 (BatchN  (None, 120, 120, 19  768        ['depthwise_conv2d_9[0][0]']
#  ormalization)                  2)
#
#  re_lu_33 (ReLU)                (None, 120, 120, 19  0           ['batch_normalization_43[0][0]']
#                                 2)
#
#  conv2d_33 (Conv2D)             (None, 120, 120, 64  12288       ['re_lu_33[0][0]']
#                                 )
#
#  batch_normalization_44 (BatchN  (None, 120, 120, 64  256        ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  conv2d_34 (Conv2D)             (None, 120, 120, 38  24576       ['batch_normalization_44[0][0]']
#                                 4)
#
#  batch_normalization_45 (BatchN  (None, 120, 120, 38  1536       ['conv2d_34[0][0]']
#  ormalization)                  4)
#
#  re_lu_34 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_45[0][0]']
#                                 4)
#
#  depthwise_conv2d_10 (Depthwise  (None, 120, 120, 38  3456       ['re_lu_34[0][0]']
#  Conv2D)                        4)
#
#  batch_normalization_46 (BatchN  (None, 120, 120, 38  1536       ['depthwise_conv2d_10[0][0]']
#  ormalization)                  4)
#
#  re_lu_35 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_46[0][0]']
#                                 4)
#
#  conv2d_35 (Conv2D)             (None, 120, 120, 64  24576       ['re_lu_35[0][0]']
#                                 )
#
#  batch_normalization_47 (BatchN  (None, 120, 120, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  add_7 (Add)                    (None, 120, 120, 64  0           ['batch_normalization_47[0][0]',
#                                 )                                 'batch_normalization_44[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 120, 120, 38  24576       ['add_7[0][0]']
#                                 4)
#
#  batch_normalization_48 (BatchN  (None, 120, 120, 38  1536       ['conv2d_36[0][0]']
#  ormalization)                  4)
#
#  re_lu_36 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_48[0][0]']
#                                 4)
#
#  depthwise_conv2d_11 (Depthwise  (None, 120, 120, 38  3456       ['re_lu_36[0][0]']
#  Conv2D)                        4)
#
#  batch_normalization_49 (BatchN  (None, 120, 120, 38  1536       ['depthwise_conv2d_11[0][0]']
#  ormalization)                  4)
#
#  re_lu_37 (ReLU)                (None, 120, 120, 38  0           ['batch_normalization_49[0][0]']
#                                 4)
#
#  conv2d_37 (Conv2D)             (None, 120, 120, 64  24576       ['re_lu_37[0][0]']
#                                 )
#
#  batch_normalization_50 (BatchN  (None, 120, 120, 64  256        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  add_8 (Add)                    (None, 120, 120, 64  0           ['batch_normalization_50[0][0]',
#                                 )                                 'add_7[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 120, 120, 64  256        ['add_8[0][0]']
#  ormalization)                  )
#
#  activation_1 (Activation)      (None, 120, 120, 64  0           ['batch_normalization_51[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 120, 120, 32  2080        ['activation_1[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 120, 120, 32  18464       ['activation_1[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 120, 120, 16  0           ['conv2d_38[0][0]',
#                                 0)                                'conv2d_39[0][0]',
#                                                                   'conv2d_40[0][0]',
#                                                                   'conv2d_41[0][0]',
#                                                                   'conv2d_42[0][0]']
#
#  dropout_5 (Dropout)            (None, 120, 120, 16  0           ['concatenate_1[0][0]']
#                                 0)
#
#  conv2d_43 (Conv2D)             (None, 120, 120, 1)  161         ['dropout_5[0][0]']
#
#  bilinear_up_sampling2d_1 (Bili  (None, 480, 480, 1)  0          ['conv2d_43[0][0]']
#  nearUpSampling2D)
#
#  CV1 (Conv2D)                   (None, 480, 480, 16  448         ['input_3[0][0]']
#                                 )
#
#  CV11 (Conv2D)                  (None, 480, 480, 16  160         ['bilinear_up_sampling2d_1[0][0]'
#                                 )                                ]
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 160, 160, 16  0          ['CV1[0][0]']
#                                 )
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 160, 160, 16  0          ['CV11[0][0]']
#                                 )
#
#  DS1 (DepthwiseConv2D)          (None, 160, 160, 16  144         ['max_pooling2d_6[0][0]']
#                                 )
#
#  DS11 (DepthwiseConv2D)         (None, 160, 160, 16  144         ['max_pooling2d_9[0][0]']
#                                 )
#
#  batch_normalization_52 (BatchN  (None, 160, 160, 16  64         ['DS1[0][0]']
#  ormalization)                  )
#
#  batch_normalization_58 (BatchN  (None, 160, 160, 16  64         ['DS11[0][0]']
#  ormalization)                  )
#
#  re_lu_38 (ReLU)                (None, 160, 160, 16  0           ['batch_normalization_52[0][0]']
#                                 )
#
#  re_lu_44 (ReLU)                (None, 160, 160, 16  0           ['batch_normalization_58[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 160, 160, 32  512         ['re_lu_38[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 160, 160, 32  512         ['re_lu_44[0][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 160, 160, 32  128        ['conv2d_44[0][0]']
#  ormalization)                  )
#
#  batch_normalization_59 (BatchN  (None, 160, 160, 32  128        ['conv2d_47[0][0]']
#  ormalization)                  )
#
#  re_lu_39 (ReLU)                (None, 160, 160, 32  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  re_lu_45 (ReLU)                (None, 160, 160, 32  0           ['batch_normalization_59[0][0]']
#                                 )
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 53, 53, 32)  0           ['re_lu_39[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 53, 53, 32)  0           ['re_lu_45[0][0]']
#  )
#
#  DS2 (DepthwiseConv2D)          (None, 53, 53, 32)   288         ['max_pooling2d_7[0][0]']
#
#  DS21 (DepthwiseConv2D)         (None, 53, 53, 32)   288         ['max_pooling2d_10[0][0]']
#
# ...
# Epoch 4: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 96s 96ms/step - loss: 0.2814 - accuracy: 0.3035 - val_loss: 0.2819 - val_accuracy: 0.3480
# Epoch 5/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.3820
# Epoch 5: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 96s 96ms/step - loss: 0.2655 - accuracy: 0.3820 - val_loss: 0.3042 - val_accuracy: 0.3540
# Epoch 6/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.4225
# Epoch 6: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 95s 95ms/step - loss: 0.2544 - accuracy: 0.4225 - val_loss: 0.2754 - val_accuracy: 0.3820
# Epoch 7/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2442 - accuracy: 0.4545
# Epoch 7: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 95s 95ms/step - loss: 0.2442 - accuracy: 0.4545 - val_loss: 0.2375 - val_accuracy: 0.4800
# Epoch 8/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.4810
# Epoch 8: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 98s 98ms/step - loss: 0.2364 - accuracy: 0.4810 - val_loss: 0.2332 - val_accuracy: 0.5330
# Epoch 9/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2264 - accuracy: 0.5085
# Epoch 9: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 95s 95ms/step - loss: 0.2264 - accuracy: 0.5085 - val_loss: 0.2446 - val_accuracy: 0.5670
# Epoch 10/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2143 - accuracy: 0.5575
# Epoch 10: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 97s 97ms/step - loss: 0.2143 - accuracy: 0.5575 - val_loss: 0.2300 - val_accuracy: 0.5700
# Epoch 11/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2045 - accuracy: 0.5940
# Epoch 11: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 95s 95ms/step - loss: 0.2045 - accuracy: 0.5940 - val_loss: 0.2433 - val_accuracy: 0.5430
# Epoch 12/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1927 - accuracy: 0.6255
# Epoch 12: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 95s 95ms/step - loss: 0.1927 - accuracy: 0.6255 - val_loss: 0.2090 - val_accuracy: 0.6000
# Epoch 13/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1801 - accuracy: 0.6700
# Epoch 13: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 95s 95ms/step - loss: 0.1801 - accuracy: 0.6700 - val_loss: 0.2186 - val_accuracy: 0.6100
# Epoch 14/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.6870
# Epoch 14: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 95s 95ms/step - loss: 0.1731 - accuracy: 0.6870 - val_loss: 0.3101 - val_accuracy: 0.5600
# Epoch 15/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.7055
# Epoch 15: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 94s 94ms/step - loss: 0.1633 - accuracy: 0.7055 - val_loss: 0.1736 - val_accuracy: 0.7150
# Epoch 16/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1562 - accuracy: 0.7240
# Epoch 16: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] -
50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9055
# Epoch 50: saving model to /content/drive/MyDrive/Programming/CV_project_HGR/checkpoint/checkfileFull_modify
# 1000/1000 [==============================] - 96s 96ms/step - loss: 0.0694 - accuracy: 0.9055 - val_loss: 0.1267 - val_accuracy: 0.8180
# 4757.733278989792

# %%
from tensorflow.keras.utils import img_to_array
from sklearn.metrics import confusion_matrix, classification_report

test_datagen_predict = ImageDataGenerator()

# Note: make sure the test data is in alphanumeric order or the predict by setting .flow(shuffle = False)
# Then the predict_generator will base on the prediction value to match the label
test_generator_predict = test_datagen_predict.flow(testImages, testLabel, batch_size=batch_size, shuffle=False)
y_pred = model.predict_generator(test_generator_predict)
print(y_pred)
print(y_pred.shape)


cm = confusion_matrix(testLabel.argmax(axis=1), y_pred.argmax(axis=1))
cr = classification_report(testLabel.argmax(axis=1), y_pred.argmax(axis=1))
print(cm)
print(cr)

## print confusion matrix 
plt.figure(figsize = (6, 6))
plt.imshow(cm, cmap=plt.cm.Blues)
indices = range(len(cm))
class_name = ["A", "B", "C", "D", "E", "F", "H", "I", "J", "K"]
plt.xticks(indices, class_name)
plt.yticks(indices, class_name)
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
for first_index in range(len(cm)):
  for second_index in range(len(cm[first_index])):
    if first_index == second_index:
      plt.text(first_index, second_index, cm[first_index][second_index], horizontalalignment='center', verticalalignment='center',color="white")
    else:
      plt.text(first_index, second_index, cm[first_index][second_index], horizontalalignment='center', verticalalignment='center',)
plt.show()
# Out:
# <ipython-input-11-cdbc3f27bb09>:9: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(test_generator_predict)
# [[9.99917388e-01 8.12871714e-11 1.49472744e-05 ... 7.04583725e-09
#   6.35264296e-05 4.09872973e-06]
#  [9.98525202e-01 2.04542765e-08 8.70525138e-04 ... 1.02968770e-07
#   3.57054669e-04 2.21183713e-04]
#  [9.99429643e-01 9.26352506e-09 1.65929698e-04 ... 1.89877003e-08
#   3.87106120e-04 1.40152879e-05]
#  ...
#  [8.45358372e-05 3.11071972e-06 2.57249456e-03 ... 8.01721064e-04
#   1.20360395e-02 9.69229519e-01]
#  [7.45867874e-05 5.77208539e-07 1.68809220e-02 ... 3.29440925e-04
#   4.89493161e-02 9.19212878e-01]
#  [3.49698821e-05 1.04434470e-07 1.00410255e-02 ... 2.81880231e-04
#   1.94244478e-02 9.64132488e-01]]
# (1000, 10)
# [[97  0  0  0  0  0  0  1  2  0]
#  [ 0 89  0  0  1  9  1  0  0  0]
#  [ 1  0 95  0  0  1  0  2  0  1]
#  [ 1  1 12 69 12  1  0  2  0  2]
#  [ 2  0  2  0 90  2  0  1  0  3]
#  [ 0 10  0  1  8 70  0 10  0  1]
#  [ 0  2  3  0  0  3 79 13  0  0]
#  [ 4  1  0  0  0  2  1 92  0  0]
#  [25  2  1  0  3  5  0  3 57  4]
#  [ 3  1  5  3  2  2  0  1  3 80]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.97      0.83       100
#            1       0.84      0.89      0.86       100
#            2       0.81      0.95      0.87       100
#            3       0.95      0.69      0.80       100
#            4       0.78      0.90      0.83       100
#            5       0.74      0.70      0.72       100
#            6       0.98      0.79      0.87       100
#            7       0.74      0.92      0.82       100
#            8       0.92      0.57      0.70       100
#            9       0.88      0.80      0.84       100
#
#     accuracy                           0.82      1000
#    macro avg       0.83      0.82      0.81      1000
# weighted avg       0.83      0.82      0.81      1000
